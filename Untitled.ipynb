# %%
# !nvidia-smi
# Out:
# Wed Dec 11 11:52:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A6000               Off | 00000000:01:00.0 Off |                  Off |
# | 30%   38C    P8              19W / 300W |      2MiB / 49140MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

# Clear previous output
display.clear_output()

# Run YOLO checks (corrected command)
# !yolo checks
# Out:
# Ultralytics 8.3.28 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Setup complete ✅ (32 CPUs, 251.5 GB RAM, 163.5/438.1 GB disk)
#
# OS                  Linux-5.15.0-52-generic-x86_64-with-glibc2.29
# Environment         Linux
# Python              3.8.10
# Install             pip
# RAM                 251.53 GB
# Disk                163.5/438.1 GB
# CPU                 AMD Ryzen Threadripper PRO 3955WX 16-Cores
# CPU count           32
# GPU                 NVIDIA RTX A6000, 48677MiB
# GPU count           2
# CUDA                12.1
#
# numpy               ✅ 1.24.4>=1.23.0
# matplotlib          ✅ 3.7.5>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# pyyaml              ✅ 5.3.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.10.1>=1.4.1
# torch               ✅ 2.4.1>=1.8.0
# torchvision         ✅ 0.19.1>=0.9.0
# tqdm                ✅ 4.67.0>=4.64.0
# psutil              ✅ 5.9.5
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Qa6MULvX4ILNcIEfuxyv")
project = rf.workspace("swai-academy").project("two-person-ride")
version = project.version(18)
dataset = version.download("yolov8")
                
                
                

# 데이터셋 경로 출력
print(f"Dataset downloaded to: {dataset.location}")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset downloaded to: /shared/home/ondevice/two-person-ride-18

# %%
# test/images 경로 확인
test_images_path = os.path.join(dataset.location, "test/images")
print(f"Path to test/images: {test_images_path}")
# Out:
# Path to test/images: /shared/home/ondevice/two-person-ride-18/test/images

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 device=0,1
# Out:
# Ultralytics 8.3.28 🚀 Python-3.8.10 torch-2.4.1+cu121 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                       CUDA:1 (NVIDIA RTX A6000, 48674MiB)
# ...

# %%
Image(filename=f'runs/detect/train33/confusion_matrix.png', width=600)

# %%
Image(filename=f'runs/detect/train33/results.png', width=600)
